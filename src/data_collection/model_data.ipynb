# %% [markdown]
# # Generating Model Data

# %% [markdown]
# The main purpose of this notebook is to use our new dataset (located in data/motley-fool-data.pkl) to create new training data for our model.

# %%
import importlib
import pandas as pd
import requests
import yfinance as yf
import os
import re
from datetime import timedelta, datetime
import time
from transformers import pipeline


import sys
project_dir = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_dir)


from models import time_series
import stockinfo as si
importlib.reload(si)
from models import sentiment
# Reload to see changes

# %%
# Globals
EARNINGS_CALL_FILE = "../../data/motley-fool-data.pkl"
SENTIMENT_SAVE_LOCATION = "../../data/2021-motley-fool-sentiment.csv"

# %%
# Load in dataset
earnings_call_df = pd.read_pickle(EARNINGS_CALL_FILE)

# %%
earnings_call_df
# Out:
#                               date      exchange        q ticker  \
# 0       Aug 27, 2020, 9:00 p.m. ET  NASDAQ: BILI  2020-Q2   BILI
# 1       Jul 30, 2020, 4:30 p.m. ET     NYSE: GFF  2020-Q3    GFF
# 2       Oct 23, 2019, 5:00 p.m. ET  NASDAQ: LRCX  2020-Q1   LRCX
# 3       Nov 6, 2019, 12:00 p.m. ET  NASDAQ: BBSI  2019-Q3   BBSI
# 4        Aug 7, 2019, 8:30 a.m. ET  NASDAQ: CSTE  2019-Q2   CSTE
# ...                            ...           ...      ...    ...
# 18750    Nov 9, 2021, 1:00 p.m. ET     NYSE: SWX  2021-Q3    SWX
# 18751  Nov 18, 2021, 12:00 p.m. ET    NYSE: PNNT  2021-Q4   PNNT
# 18752  Feb 08, 2022, 11:00 a.m. ET     NYSE: TDG  2022-Q1    TDG
# 18753   Feb 28, 2022, 4:30 p.m. ET  NASDAQ: DVAX  2021-Q4   DVAX
# 18754   Aug 12, 2021, 9:00 a.m. ET   (NYSE: CIB)  2021-Q2   CIB)
#
#                                               transcript
# 0      Prepared Remarks:\nOperator\nGood day, and wel...
# 1      Prepared Remarks:\nOperator\nThank you for sta...
# 2      Prepared Remarks:\nOperator\nGood day and welc...
# 3      Prepared Remarks:\nOperator\nGood day, everyon...
# 4      Prepared Remarks:\nOperator\nGreetings and wel...
# ...                                                  ...
# 18750  Prepared Remarks:\nOperator\nLadies and gentle...
# 18751  Prepared Remarks:\nOperator\nGood morning, and...
# 18752  Prepared Remarks:\nOperator\nThank you for sta...
# 18753  Prepared Remarks:\nOperator\nGood day, ladies ...
# 18754  Prepared Remarks:\nOperator\nGood morning, lad...
#
# [18755 rows x 5 columns]

# %% [markdown]
# We're only going to use sp_500 earnings calls since this dataset is large, and it takes a while to generate sentiment scores. Within this subset, we're also going to use only 500 earnings calls.

# %%
# Filter out non-sp500 tickers
sp500_tickers = si.get_sp500_tickers()
sp500_earnings_call_df = earnings_call_df[earnings_call_df['ticker'].isin(sp500_tickers)]
# sp500_earnings_call_df = sp500_earnings_call_df[sp500_earnings_call_df['q'].str.startswith("2021")]


# Randomly select 500
sp500_earnings_call_small_df = sp500_earnings_call_df.sample(n=500, random_state=1)

# Shape the dataset so it works well with finbert handler
# Extract just the date portion and combine with ticker
sentiment_df = sp500_earnings_call_small_df.copy()
sentiment_df['ticker'] = sentiment_df['ticker'] + '_' + sentiment_df['date'].str.split(',').str[0] + sentiment_df['date'].str.split(',').str[1]
sentiment_df = sentiment_df[['ticker', 'transcript']].rename(columns={'transcript': 'text'})
sentiment_df['text'] = sentiment_df['text'].apply(si.clean_transcript)

# %%
# Load file if it exists, if not runs sentiment (could take upwards of an hour)
if os.path.exists(SENTIMENT_SAVE_LOCATION):
    sentiment_df = pd.read_csv(SENTIMENT_SAVE_LOCATION, index_col=0)

sentiment_df = sentiment.finbert_handler(sentiment_df)
sentiment_df.to_csv(SENTIMENT_SAVE_LOCATION, index=True)
# Out:
# Processing documents:   1%|          | 3/500 [00:11<31:37,  3.82s/document]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[145], line 5
#       1 # Load file if it exists, if not runs sentiment (could take upwards of an hour)
#       2 # if os.path.exists(SENTIMENT_SAVE_LOCATION):
#       3 #     sentiment_df = pd.read_csv(SENTIMENT_SAVE_LOCATION, index_col=0)
# ----> 5 sentiment_df = sentiment.finbert_handler(sentiment_df)
#       6 sentiment_df.to_csv(SENTIMENT_SAVE_LOCATION, index=True)
#
# File ~/Documents/cornell/fa24/cs4701/PC_RinehiML_brb227_gwr47_igp4_jkc97_rjc398/models/sentiment.py:183, in finbert_handler(data_input, batch_size, max_files)
#     181 for i in tqdm(range(0, len(sentences), batch_size), desc='Processing sentences', leave=False, unit='batch', total=num_batches):
#     182     batch_sentences = sentences[i:i+batch_size]
# --> 183     batch_intensities = finbert_sentiment_intensity_batch(
#     184         batch_sentences, model, tokenizer, device, batch_size
#     185     )
#     186     intensities.extend(batch_intensities)
#     188 overall_sentiment, avg_intensity, mean_neg, mean_neu, mean_pos = aggregate_intensity_scores(intensities)
#
# File ~/Documents/cornell/fa24/cs4701/PC_RinehiML_brb227_gwr47_igp4_jkc97_rjc398/models/sentiment.py:108, in finbert_sentiment_intensity_batch(texts, model, tokenizer, device, batch_size)
#     105 inputs = tokenizer(batch_texts, return_tensors='pt',
#     106                    truncation=True, max_length=512, padding=True).to(device)
#     107 with torch.no_grad():
# --> 108     outputs = model(**inputs)
#     110 probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
#     111 batch_intensities = probs.cpu().numpy().tolist()
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:1696, in BertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1688 r"""
#    1689 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1690     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1691     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1692     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1693 """
#    1694 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1696 outputs = self.bert(
#    1697     input_ids,
#    1698     attention_mask=attention_mask,
#    1699     token_type_ids=token_type_ids,
#    1700     position_ids=position_ids,
#    1701     head_mask=head_mask,
#    1702     inputs_embeds=inputs_embeds,
#    1703     output_attentions=output_attentions,
#    1704     output_hidden_states=output_hidden_states,
#    1705     return_dict=return_dict,
#    1706 )
#    1708 pooled_output = outputs[1]
#    1710 pooled_output = self.dropout(pooled_output)
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:1142, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1135 # Prepare head mask if needed
#    1136 # 1.0 in head_mask indicate we keep the head
#    1137 # attention_probs has shape bsz x n_heads x N x N
#    1138 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1139 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1140 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1142 encoder_outputs = self.encoder(
#    1143     embedding_output,
#    1144     attention_mask=extended_attention_mask,
#    1145     head_mask=head_mask,
#    1146     encoder_hidden_states=encoder_hidden_states,
#    1147     encoder_attention_mask=encoder_extended_attention_mask,
#    1148     past_key_values=past_key_values,
#    1149     use_cache=use_cache,
#    1150     output_attentions=output_attentions,
#    1151     output_hidden_states=output_hidden_states,
#    1152     return_dict=return_dict,
#    1153 )
#    1154 sequence_output = encoder_outputs[0]
#    1155 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:695, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     684     layer_outputs = self._gradient_checkpointing_func(
#     685         layer_module.__call__,
#     686         hidden_states,
#    (...)
#     692         output_attentions,
#     693     )
#     694 else:
# --> 695     layer_outputs = layer_module(
#     696         hidden_states,
#     697         attention_mask,
#     698         layer_head_mask,
#     699         encoder_hidden_states,
#     700         encoder_attention_mask,
#     701         past_key_value,
#     702         output_attentions,
#     703     )
#     705 hidden_states = layer_outputs[0]
#     706 if use_cache:
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:627, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     624     cross_attn_present_key_value = cross_attention_outputs[-1]
#     625     present_key_value = present_key_value + cross_attn_present_key_value
# --> 627 layer_output = apply_chunking_to_forward(
#     628     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     629 )
#     630 outputs = (layer_output,) + outputs
#     632 # if decoder, return the attn key/values as the last output
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/transformers/pytorch_utils.py:248, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     245     # concatenate output at same dimension
#     246     return torch.cat(output_chunks, dim=chunk_dim)
# --> 248 return forward_fn(*input_tensors)
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:640, in BertLayer.feed_forward_chunk(self, attention_output)
#     638 def feed_forward_chunk(self, attention_output):
#     639     intermediate_output = self.intermediate(attention_output)
# --> 640     layer_output = self.output(intermediate_output, attention_output)
#     641     return layer_output
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:552, in BertOutput.forward(self, hidden_states, input_tensor)
#     551 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 552     hidden_states = self.dense(hidden_states)
#     553     hidden_states = self.dropout(hidden_states)
#     554     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/cs4701demo/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
sentiment_df
# Out:
#                  ticker finbert_sentiment  sentiment_intensity  mean_neg_prob  \
# 4351   AMZN_Jul 30 2020          positive             0.309188       0.063605
# 7691    DOC_Feb 25 2021          positive             0.272611       0.056223
# 14542  AXON_Nov 15 2021          positive             0.300484       0.040746
# 14036   OXY_Aug 04 2021          positive             0.311152       0.034610
# 10361  SPGI_Apr 28 2020          negative             0.144456       0.123690
# ...                 ...               ...                  ...            ...
# 9120    EQR_Oct 28 2020          negative             0.051895       0.091274
# 14726  LULU_Dec 09 2021          positive             0.383679       0.054998
# 9769    NWS_May. 9 2019          positive             0.266291       0.113507
# 13983   AIG_Aug 06 2021          positive             0.347043       0.036450
# 9107    KMX_Apr 01 2021          positive             0.261530       0.061442
#
#        mean_neu_prob  mean_pos_prob
# 4351        0.563601       0.372793
# 7691        0.614944       0.328834
# 14542       0.618025       0.341230
# 14036       0.619629       0.345761
# 10361       0.608163       0.268147
# ...              ...            ...
# 9120        0.765557       0.143169
# 14726       0.506325       0.438677
# 9769        0.506695       0.379798
# 13983       0.580057       0.383493
# 9107        0.615587       0.322971
#
# [500 rows x 6 columns]

# %% [markdown]
# Here we do some date conversion to prepare it for the `collect_all_features` function.

# %%
earnings_calls_with_sentiment_df = sentiment_df.rename(columns={'ticker': 'sentiment_ticker'}).join(sp500_earnings_call_small_df[['date', 'ticker']])
# convert date to datetime format
earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
earnings_calls_with_sentiment_df.dropna(inplace=True)

# Convert date to start_date in YYYY-MM-DD format
earnings_calls_with_sentiment_df['start_date'] = earnings_calls_with_sentiment_df['date'].dt.strftime('%Y-%m-%d')

# Create end_date by adding 90 days to the date
earnings_calls_with_sentiment_df['prediction_date'] = (earnings_calls_with_sentiment_df['date'] + pd.Timedelta(days=90)).dt.strftime('%Y-%m-%d')
# Out:
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 30, 2020, 5:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 25, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 15, 2021, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 04, 2021, 1:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 28, 2020, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 18, 2021, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 12, 2019, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jan 26, 2021, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 29, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 28, 2021, 12:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 30, 2020, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 29, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 11, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 04, 2021, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jan 26, 2022, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 23, 2020, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 22, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 4, 2021, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 30, 2019, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 6, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 28, 2022, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 29, 2021, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 23, 2019, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 27, 2022, 1:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 19, 2022, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 27, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 6, 2020, 12:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 20, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 04, 2020, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jan 26, 2021, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "April 16, 2019, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "April 28, 2020, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 5, 2021, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 20, 2022, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 22, 2021, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 29, 2021, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 01, 2022, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 10, 2022, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 01, 2022, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 03, 2022, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 21, 2019, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 5, 2021, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 28, 2020, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 23, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 27, 2021, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 26, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 22, 2020, 6:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 04, 2022, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Mar 17, 2022, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 06, 2021, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 27, 2021, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jan 29, 2020, 6:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 03, 2022, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 01, 2022, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 26, 2021, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 23, 2022, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 19, 2021, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 19, 2021, 12:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 31, 2019, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 18, 2022, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jan 26, 2022, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 29, 2020, 5:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 24, 2021, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 18, 2022, 6:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 19, 2022, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Dec 12, 2022, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 25, 2022, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 03, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 18, 2022, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jan 23, 2020, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 15, 2021, 12:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 24, 2021, 11:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 4, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 21, 2020, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 10, 2022, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 04, 2021, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 30, 2021, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 28, 2021, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 21, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 31, 2019, 1:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jan 13, 2023, 8:45 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jan 27, 2021, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 4, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 29, 2021, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 2, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 12, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 10, 2021, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 23, 2020, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 24, 2019, 5:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 08, 2022, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 02, 2021, 9:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# ...
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 30, 2020, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jul 28, 2022, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 29, 2021, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jan 28, 2022, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 21, 2021, 10:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 04, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 07, 2023, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Sep 22, 2022, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 19, 2021, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Jun 03, 2021, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Sep 29, 2021, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 22, 2022, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 24, 2020, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 5, 2019, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 27, 2021, 1:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 26, 2022, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Feb 24, 2021, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Mar 16, 2021, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May 05, 2022, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 21, 2022, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 29, 2022, 12:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 17, 2021, 8:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Dec 20, 2021, 10:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 17, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Nov 2, 2021, 12:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Oct 28, 2020, 11:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Dec 09, 2021, 4:30 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "May. 9, 2019, 5:00 p.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Aug 06, 2021, 8:30 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')
# /var/folders/15/8q1pvppj40b6gcq695yybpcc0000gn/T/ipykernel_21088/3777661508.py:3: FutureWarning: Parsed string "Apr 01, 2021, 9:00 a.m. ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   earnings_calls_with_sentiment_df['date'] = pd.to_datetime(earnings_calls_with_sentiment_df['date'], infer_datetime_format=True, errors='coerce')

# %%
from stockinfo import collect_all_features

dataset = {}

# For each row in df, collect all features during that time period
for index, row in earnings_calls_with_sentiment_df.iterrows():
    try:
        ticker = row['ticker']
        start_date = row['start_date']
        prediction_date = row['prediction_date']

        features = collect_all_features(ticker, start_date, prediction_date, None, None, None)
        features['Earnings_Call_Sentiment'] = row['sentiment_intensity']
        features['sentiment_mean_neg_prob'] = row['mean_neg_prob']
        features['sentiment_mean_pos_prob'] = row['mean_pos_prob']
        features['sentiment_mean_neu_prob'] = row['mean_neu_prob']
        features.dropna(inplace=True)
        dataset[row['sentiment_ticker']] = features
    except:
        continue

# %% [markdown]
# Now we shape it into a single numpy array in sequnec format (using `prepare_sequence_data`) and save it.

# %%
target_column = 'Close'
target_idx = 3
look_back = 10
look_forward = 5
processed_data = {}

for id, data in dataset.items():
    X, y = time_series.prepare_sequence_data(data.values, look_back, look_forward, target_idx)
    if len(X.shape) != 3:
        print(f"Skipping {ticker} (unexpected X shape: {X.shape})")
        continue
    processed_data[id] = {'X': X, 'y': y}

# %%
import numpy as np
test_data = processed_data.popitem()
X_test = test_data[1]['X']
y_test = test_data[1]['y']

TRAINING_DATA_DIR = '../../models/training_data'

np.save(f'{TRAINING_DATA_DIR}/motley_X_test.npy', X_test)
np.save(f'{TRAINING_DATA_DIR}/motley_y_test.npy', y_test)

X_combined = np.vstack([seq['X'] for seq in processed_data.values()])
y_combined = np.concatenate([seq['y'] for seq in processed_data.values()])

np.save(f'{TRAINING_DATA_DIR}/motley_X_combined.npy', X_combined)
np.save(f'{TRAINING_DATA_DIR}/motley_y_combined.npy', y_combined)
